# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the csv file
df = pd.read_csv('Used_Bikes.csv')
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.tail()
# Out:
#                        bike_name    price    city  kms_driven        owner  \
# 32643     Hero Passion Pro 100cc  39000.0   Delhi     22000.0  First Owner
# 32644       TVS Apache RTR 180cc  30000.0  Karnal      6639.0  First Owner
# 32645   Bajaj Avenger Street 220  60000.0   Delhi     20373.0  First Owner
# 32646  Hero Super Splendor 125cc  15600.0  Jaipur     84186.0  First Owner
# 32647         Bajaj Pulsar 150cc  22000.0    Pune     60857.0  First Owner
#
#         age  power  brand
# 32643   4.0  100.0   Hero
# 32644   9.0  180.0    TVS
# 32645   6.0  220.0  Bajaj
# 32646  16.0  125.0   Hero
# 32647  13.0  150.0  Bajaj

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
#mean and median 
mean_price = df['price'].mean()
mean_price
# Out:
# 84883.90005461496

# %%
median_price = df['price'].median()
median_price
# Out:
# 43000.0

# %% [markdown]
# ### 1. What is the distribution of bike prices?

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], bins=50, kde=True)
plt.title('Distribution of Bike Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
#The distribution of bike prices shows that most bike prices are clustered at the lower end, with a long tail towards
#the higher end.

# %% [markdown]
# ### 2. How does the price vary by city?

# %%
price_by_city = df.groupby('city')['price'].describe()
price_by_city.sort_values(by='mean', ascending=False).head(10)
# Out:
#              count          mean            std        min        25%  \
# city
# Chandrapur     1.0  1.250000e+06            NaN  1250000.0  1250000.0
# Hubli          4.0  8.105250e+05  796204.150433   108400.0   127375.0
# Koppal         1.0  7.500000e+05            NaN   750000.0   750000.0
# Berhampur      2.0  7.100000e+05       0.000000   710000.0   710000.0
# Jajpur         1.0  5.694000e+05            NaN   569400.0   569400.0
# Rajnandgaon    1.0  5.100000e+05            NaN   510000.0   510000.0
# Hanumangarh    2.0  4.500000e+05       0.000000   450000.0   450000.0
# Jodhpur      635.0  4.395969e+05   64815.228690    18000.0   450000.0
# Sangli         1.0  3.910000e+05            NaN   391000.0   391000.0
# Vapi           3.0  3.800000e+05  103923.048454   260000.0   350000.0
#
#                    50%        75%        max
# city
# Chandrapur   1250000.0  1250000.0  1250000.0
# Hubli         816850.0  1500000.0  1500000.0
# Koppal        750000.0   750000.0   750000.0
# ...

# %% [markdown]
# ### 3. What are the most common bike brands in the dataset?

# %%
plt.figure(figsize=(10, 6))
top_brands = df['brand'].value_counts().nlargest(10)
colors = sns.color_palette("husl", len(top_brands))  # Using the "husl" palette for diverse colors
sns.barplot(x=top_brands.index, y=top_brands.values, hue=top_brands.index, palette=colors, dodge=False)
plt.title('Top 10 Most Common Bike Brands')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend([], [], frameon=False)  # Removing the legend as it is not necessary
plt.show()

# %% [markdown]
# ### 4. Which cities have the most used bikes listed for sale?

# %%
plt.figure(figsize=(10, 6))
top_cities = df['city'].value_counts().nlargest(10)
colors = sns.color_palette("husl", len(top_cities))  # Using the "husl" palette for diverse colors
sns.barplot(x=top_cities.index, y=top_cities.values,hue = top_cities.index, palette=colors,dodge=False)
plt.title('Top 10 Cities with Most Used Bikes Listed for Sale')
plt.xlabel('City')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend([],[],frameon=False)
plt.show()

# %% [markdown]
# ### 5. Which brands have the highest average power?

# %%
# Calculate average power by brand
average_power_by_brand = df.groupby('brand')['power'].mean().sort_values(ascending=False)

# Plot the top 10 brands with the highest average power
plt.figure(figsize=(12, 6))
average_power_by_brand.head(10).plot(kind='bar', color='orange')
plt.title('Top 10 Brands with Highest Average Power')
plt.xlabel('Brand')
plt.ylabel('Average Power (cc)')
plt.xticks(rotation=45)
plt.show()

average_power_by_brand.head(10)
# Out:
# brand
# Indian             1353.333333
# Ducati             1016.136364
# Triumph             893.076923
# MV                  872.500000
# Harley-Davidson     758.204885
# Kawasaki            570.886076
# BMW                 463.750000
# Hyosung             400.000000
# Benelli             380.285714
# Royal Enfield       366.104596
# Name: power, dtype: float64

# %% [markdown]
# ### 7. What is the distribution of bike power?

# %%
plt.figure(figsize=(10, 6))
sns.histplot(used_bikes_df['power'], bins=50, kde=True)
plt.title('Distribution of Bike Power')
plt.xlabel('Power (cc)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 8. Which city has the highest average bike power?

# %%
# Calculate average power by city
average_power_by_city = df.groupby('city')['power'].mean().sort_values(ascending=False)

# Plot the top 10 cities with the highest average bike power
plt.figure(figsize=(12, 6))
average_power_by_city.head(10).plot(kind='bar', color='green')
plt.title('Top 10 Cities with Highest Average Bike Power')
plt.xlabel('City')
plt.ylabel('Average Power (cc)')
plt.xticks(rotation=45)
plt.show()

average_power_by_city.head(10)
# Out:
# city
# Chandrapur              1300.000000
# Koppal                  1050.000000
# Berhampur                900.000000
# Jajpur                   899.000000
# Rajnandgaon              750.000000
# Sangli                   750.000000
# Hanumangarh              750.000000
# Jodhpur                  734.283465
# Dadra & Nagar Haveli     650.000000
# Davanagere               650.000000
# Name: power, dtype: float64

# %% [markdown]
# ### 9. What are the average prices of bikes for the top 5 brands?

# %%
top_5_brands = df['brand'].value_counts().head(5).index
average_price_top_5_brands = df[used_bikes_df['brand'].isin(top_5_brands)].groupby('brand')['price'].mean()
average_price_top_5_brands
# Out:
# brand
# Bajaj            48331.268082
# Hero             23829.453518
# Honda            59230.474383
# Royal Enfield    98562.072044
# Yamaha           57068.964249
# Name: price, dtype: float64
